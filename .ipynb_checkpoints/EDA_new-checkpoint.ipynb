# %% [markdown]
# ##  Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ## Loading data from CSV

# %%
# Load datasets
alberta_df = pd.read_csv('Alberta.csv')
manitoba_df = pd.read_csv('Manitoba.csv')
ontario_df = pd.read_csv('Ontario.csv')
quebec_df = pd.read_csv('Quebec.csv')
vancouver_df = pd.read_csv('Vancouver.csv')

# Clean datasets by removing rows where 'rating' is 0
alberta_cleaned = df[df['rating'] != 0]
manitoba_cleaned = df[df['rating'] != 0]
ontario_cleaned = df[df['rating'] != 0]
quebec_cleaned = df[df['rating'] != 0]
vancouver_cleaned = df[df['rating'] != 0]

# Save cleaned datasets
alberta_cleaned.to_csv('Alberta_cleaned.csv', index=False)
manitoba_cleaned.to_csv('Manitoba_cleaned.csv', index=False)
ontario_cleaned.to_csv('Ontario_cleaned.csv', index=False)
quebec_cleaned.to_csv('Quebec_cleaned.csv', index=False)
vancouver_cleaned.to_csv('Vancouver_cleaned.csv', index=False)

# Load cleaned datasets for analysis
df = pd.read_csv(r"C:\Users\Dell\Desktop\Final project\Alberta_cleaned.csv")
df = pd.read_csv(r"C:\Users\Dell\Desktop\Final project\Manitoba_cleaned.csv")
df = pd.read_csv(r"C:\Users\Dell\Desktop\Final project\Ontario_cleaned.csv")
df = pd.read_csv(r"C:\Users\Dell\Desktop\Final project\Quebec_cleaned.csv")
df = pd.read_csv(r"C:\Users\Dell\Desktop\Final project\Vancouver_cleaned.csv")

# %% [markdown]
# ## Visualizing rating distribution with histogram

# %%
# Assuming 'df' is the DataFrame with a 'rating' column
plt.figure(figsize=(10, 6))
sns.histplot(df['rating'], kde=True, bins=20, color='#6666FF')

# Customize the x-axis ticks
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Quantity')

# Set x-ticks to show intervals
xticks = np.arange(0, 5.5, 0.5)
plt.xticks(xticks)
plt.grid(False)
plt.show()

# %% [markdown]
# ## Visualizing distributions of various ratings (food, service, ambience, value)

# %%
# Assuming your DataFrame is named 'df' and it contains the columns 'food', 'service', 'ambience', 'value'
columns = ['food', 'service', 'ambience', 'value'] 

# Titles and x-labels for the subplots
titles = ['Distribution of Food Ratings', 'Distribution of Service Ratings', 
          'Distribution of Ambience Ratings', 'Distribution of Value Ratings']
x_labels = ['Food Rating', 'Service Rating', 'Ambience Rating', 'Value Rating']

plt.figure(figsize=(14, 10))

# Create a histogram for each specified column
for i, column in enumerate(columns):
    plt.subplot(2, 2, i + 1)  # Create a 2x2 grid of subplots
    sns.histplot(df[column], kde=True, bins=20, color='#6666FF')
    
    # Customize the x-axis ticks and labels
    plt.title(titles[i])
    plt.xlabel(x_labels[i])  # Use the corresponding x-label for each subplot
    plt.ylabel('Quantity')

    # Set x-ticks to show intervals of 0.5, excluding 0.0
    xticks = np.arange(0, 5.5, 0.5)
    plt.xticks(xticks)
    plt.grid(False)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Generating a WordCloud from customer comments

# %%
text = ' '.join(df['comments'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud of Customer Comments')
plt.show()

# %% [markdown]
# ## Analyzing Top 10 food types in restaurants

# %%
# Assuming 'df' is your DataFrame
top_food_types = df['food_type'].value_counts().nlargest(10).index

plt.figure(figsize=(12, 6))
sns.countplot(data=df[df['food_type'].isin(top_food_types)], y='food_type', order=top_food_types, color='#6666FF')
plt.title('Top 10 Restaurants by Food Type')
plt.xticks(rotation=0)
plt.ylabel('')
plt.grid(False)
plt.show()

# %% [markdown]
# ## Scatter Plot of food vs. service ratings

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='food', y='service', data=df, color='#6666FF')
plt.title('Food vs. Service Ratings')
plt.xlabel('Food Rating')
plt.ylabel('Service Rating')
plt.grid(False)
plt.show()

# %% [markdown]
# ## Top 10 Restaurants by rating

# %%
# Assuming df is your DataFrame containing restaurant data
top_ratings = df.nlargest(10, 'rating') 

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_ratings['rest_name'], top_ratings['rating'], color='#6666FF')
plt.title('Top 10 Restaurants by Rating')
plt.xlabel('Rating') 
plt.ylabel('Restaurant Name') 
plt.gca().invert_yaxis()  
plt.grid(False)
plt.show()

# %% [markdown]
# ## Top 10 Restaurants by number of reviews

# %%
# Get the top 10 restaurants based on the highest ratings
top_expensive = df.nlargest(10, 'rating')

# Check if there are any missing values in the restaurant names
# Replace missing names with 'Unknown Restaurant' (if any)
top_expensive['rest_name'].fillna('Unknown Restaurant', inplace=True)

# Ensure that restaurant names are treated as strings in case of any datatype inconsistencies
top_expensive['rest_name'] = top_expensive['rest_name'].astype(str)

# Sort the top restaurants by the number of reviews in descending order
top_expensive = top_expensive.sort_values(by='number_of_reviews', ascending=False)

# Create a bar chart for the number of reviews
plt.figure(figsize=(10, 6))
plt.barh(top_expensive['rest_name'], top_expensive['number_of_reviews'], color='#6666FF')
plt.title('Top 10 Restaurants by Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Restaurant Name')
plt.gca().invert_yaxis() 
plt.grid(False)  
plt.show()

# %% [markdown]
# ## Distribution of coupon types

# %%
# Assuming 'df' is your DataFrame containing the 'coupon' information
food_counts = df['coupon'].value_counts().nlargest(5)  # Get the top 5 food types

# Define a function for autopct to show both percentage and count
def func(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return f"{pct:.1f}% ({absolute})"

# Create a pie chart for the top 5 food types
plt.figure(figsize=(5, 5))
plt.pie(food_counts, labels=food_counts.index, 
        autopct=lambda pct: func(pct, food_counts), startangle=140)
plt.title('Distribution of coupon')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ## Correlation heatmap

# %%
# Compute the correlation matrix
corr = df[['rating', 'food', 'service', 'ambience', 'value', 'number_of_reviews']].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, annot=True, fmt='.2f', cmap='RdYlGn', vmin=-1, vmax=1, center=0)

# Add title
plt.title('Correlation Heatmap (Lower Triangle)')
plt.show()

# %%
# Filter out rows where 'number_of_reviews' is 0
df_filtered = df[df['number_of_reviews'] > 1]

# Create the scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='number_of_reviews', y='rating', data=df_filtered)
plt.title('Scatter Plot with Regression Line for Rating vs. Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Rating')
plt.show()

# %%
# Prepare the data
X = df[['food']]  # Choose one independent variable
y = df['rating']  # Dependent variable

# Create and fit the regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Data Points')  # Scatter plot of actual data
plt.plot(X, y_pred, color='red', label='Regression Line')  # Regression line
plt.title('Regression Line for Rating vs Food')
plt.xlabel('Food')
plt.ylabel('Rating')
plt.legend()
plt.grid()
plt.show()

# %%
# Prepare the data
X6 = df[['number_of_reviews']]

# Create and fit the regression model
model6 = LinearRegression()
model6.fit(X6, y)

# Make predictions
y_pred6 = model6.predict(X6)

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(X6, y, color='blue', label='Data Points')  # Scatter plot of actual data
plt.plot(X6, y_pred6, color='red', label='Regression Line')  # Regression line
plt.title('Regression Line for Rating vs Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Rating')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Top 10 Restaurants by number of reviews

# %%
# Concatenate the DataFrames
all_data = pd.concat([alberta_df, manitoba_df, ontario_df, quebec_df, vancouver_df])

# Convert 'number_of_reviews' to numeric, forcing errors to NaN
all_data['number_of_reviews'] = pd.to_numeric(all_data['number_of_reviews'], errors='coerce')

# Drop rows with NaN in 'number_of_reviews'
all_data.dropna(subset=['number_of_reviews'], inplace=True)

# Get the top 10 restaurants by number of reviews
top_10_restaurants = all_data.nlargest(10, 'number_of_reviews')

# Create a bar plot for the top 10 restaurants with specific color
plt.figure(figsize=(10,6))
sns.barplot(x='number_of_reviews', y='rest_name', data=top_10_restaurants, color='#6666FF')
plt.title('Top 10 Restaurants by Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Restaurant Name')
plt.show()

# %% [markdown]
# ## Top 10 Restaurants by number of reviews (Categorized by City)

# %%
# Add a 'city' column to each DataFrame
Alberta['city'] = 'Alberta' 
Manitoba['city'] = 'Manitoba'
Ontario['city'] = 'Ontario'
Quebec['city'] = 'Quebec'
Vancouver['city'] = 'Vancouver'

# Concatenate the DataFrames
all_data = pd.concat([Alberta, Manitoba, Ontario, Quebec, Vancouver])

# Convert 'number_of_reviews' to numeric, forcing errors to NaN
all_data['number_of_reviews'] = pd.to_numeric(all_data['number_of_reviews'], errors='coerce')

# Drop rows with NaN in 'number_of_reviews'
all_data.dropna(subset=['number_of_reviews'], inplace=True)

# Get the top 10 restaurants by number of reviews
top_10_restaurants = all_data.nlargest(10, 'number_of_reviews')

# Create a bar plot for the top 10 restaurants, colored by city
plt.figure(figsize=(10,6))
sns.barplot(x='number_of_reviews', y='rest_name', hue='city', data=top_10_restaurants)
plt.title('Top 10 Restaurants by Number of Reviews (with City)')
plt.xlabel('Number of Reviews')
plt.ylabel('Restaurant Name')
plt.legend(title='City', loc='upper right')
plt.show()

# %% [markdown]
# ## Top 5 restaurants with best service in Alberta

# %%
# Get top 5 restaurants by service in Alberta
top_5_service = Alberta.nlargest(5, 'service')

# Create a bar plot for top 5 restaurants by service with specific color
plt.figure(figsize=(8,5))
sns.barplot(x='service', y='rest_name', data=top_5_service, color='#6666FF')
plt.title('Top 5 Restaurants with Best Service in Alberta')
plt.xlabel('Service Rating')
plt.ylabel('Restaurant Name')
plt.show()

# %% [markdown]
# ##  Number of unique food types by city

# %%
# Add a 'city' column to each DataFrame
alberta_df['city'] = 'Alberta'
manitoba_df['city'] = 'Manitoba'
ontario_df['city'] = 'Ontario'
quebec_df['city'] = 'Quebec'
vancouver_df['city'] = 'Vancouver'

# Concatenate the DataFrames
combined_data = pd.concat([alberta_df, manitoba_df, ontario_df, quebec_df, vancouver_df])

# Count the unique food types for each city and sort by descending order
food_types_per_city = combined_data.groupby('city')['food_type'].nunique()
food_types_per_city_sorted = food_types_per_city.sort_values(ascending=False)

# Plot the sorted bar plot
plt.figure(figsize=(10, 6))
food_types_per_city_sorted.plot(kind='bar', color='#6666FF')
plt.title('Number of Unique Food Types by City (Ordered by Count)', fontsize=14)
plt.xlabel('City', fontsize=12)
plt.ylabel('Number of Unique Food Types', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Most common food types across cities

# %%
# Combining the datasets and grouping for pie chart data
most_common_food = pd.concat([Alberta, Manitoba, Ontario, Quebec, Vancouver]) \
    .groupby(['city', 'food_type']).size().idxmax()

# Preparing data for pie chart
common_food_count = pd.concat([Alberta, Manitoba, Ontario, Quebec, Vancouver]) \
    .groupby(['food_type']).size().sort_values(ascending=False).head(5)

# Define a function for autopct to show both percentage and count
def func(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return f"{pct:.1f}% ({absolute})"

# Plotting pie chart
plt.figure(figsize=(6, 6))
plt.pie(common_food_count, labels=common_food_count.index, 
        autopct=lambda pct: func(pct, common_food_count), startangle=140)
plt.title('Most Common Food Types')
plt.axis('equal')  
plt.show()

# %%
# Define a function to create enhanced regression plots for various relationships
def regression_plot(x, y, data, x_label, y_label, title, color='blue'):
    plt.figure(figsize=(10, 6))
    sns.regplot(x=x, y=y, data=data, scatter_kws={'alpha': 0.5, 'color': color}, line_kws={"color": "red"})
    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=14)
    plt.ylabel(y_label, fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

# 1. Rating vs. Number of Reviews
regression_plot(x='number_of_reviews', y='rating', data=all_data,
                x_label='Number of Reviews', y_label='Rating',
                title='Rating vs. Number of Reviews with Regression Line')

# 2. Service Rating vs. Food Rating
regression_plot(x='food', y='service', data=all_data,
                x_label='Food Rating', y_label='Service Rating',
                title='Service Rating vs. Food Rating with Regression Line', color='green')

# 3. Value Rating vs. Ambience Rating
regression_plot(x='ambience', y='value', data=all_data,
                x_label='Ambience Rating', y_label='Value Rating',
                title='Value Rating vs. Ambience Rating with Regression Line', color='purple')
