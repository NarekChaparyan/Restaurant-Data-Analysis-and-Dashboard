# %%
import os
import pandas as pd
from dash import Dash, dcc, html, Input, Output
from openai import OpenAI

# Load the datasets
chicago_df = pd.read_csv('~/desktop/Project_7/Chicago.csv')
los_angeles_df = pd.read_csv('~/desktop/Project_7/Los Angeles.csv')
new_york_df = pd.read_csv('~/desktop/Project_7/New York.csv')
san_francisco_df = pd.read_csv('~/desktop/Project_7/San Francisco.csv')
san_diego_df = pd.read_csv('~/desktop/Project_7/San Diego.csv')

# Combine datasets into one DataFrame with an additional 'city' column
chicago_df['city'] = 'Chicago'
los_angeles_df['city'] = 'Los Angeles'
new_york_df['city'] = 'New York'
san_francisco_df['city'] = 'San Francisco'
san_diego_df['city'] = 'San Diego'
df = pd.concat([chicago_df, los_angeles_df, new_york_df, san_francisco_df, san_diego_df])

# Set up OpenAI client
client = OpenAI(api_key="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")

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("Restaurant Data Analysis", style={'text-align': 'center', 'color': '#FFFFFF'}),

    # Dropdown for selecting city with placeholder text
    dcc.Dropdown(
        id='city-dropdown',
        options=[{'label': city, 'value': city} for city in df['city'].unique()],
        placeholder='Select the city',  # Placeholder text
        clearable=False,
        style={'margin-bottom': '20px', 'font-size': '18px'}
    ),

    # Filter fields for rating and number_of_reviews, initially hidden
    html.Div(id='filters-container', style={'display': 'none'}, children=[
        html.Label("Rating Range", style={'color': 'black'}),  # Changed to black
        dcc.RangeSlider(
            id='rating-slider',
            min=0, max=5, step=0.5, value=[0, 5],
            marks={i: str(i) for i in range(6)},
            tooltip={"placement": "bottom", "always_visible": True}
        ),
        
        html.Br(),

        html.Label("Number of Reviews Range", style={'color': 'black'}),  # Changed to black
        dcc.RangeSlider(
            id='review-slider',
            min=0, max=12000, step=500, value=[0, 12000],
            marks={i: f"{i}" for i in range(0, 12001, 1000)},
            tooltip={"placement": "bottom", "always_visible": True}
        ),
        
        html.Br(),
        html.Label("Select a Restaurant", style={'color': '#FFFFFF'}),
        dcc.Dropdown(id='restaurant-dropdown', clearable=False, style={'margin-bottom': '20px', 'font-size': '18px'})
    ]),

    # Placeholder for restaurant details and summary
    html.Div(id='graphs-container', style={'margin-top': '20px'})
], style={
    'background': 'linear-gradient(to right, #f2b8b8, #e23d3d)',  # Gradient background
    'padding': '40px',
    'font-family': 'Arial, sans-serif'
})

# Callback to show filters when a city is selected
@app.callback(
    Output('filters-container', 'style'),
    Input('city-dropdown', 'value')
)
def toggle_filters(selected_city):
    if selected_city:
        return {'display': 'block'}
    else:
        return {'display': 'none'}

# Callback to update the restaurant dropdown based on city and filters
@app.callback(
    Output('restaurant-dropdown', 'options'),
    Input('city-dropdown', 'value'),
    Input('rating-slider', 'value'),
    Input('review-slider', 'value')
)
def update_restaurant_options(selected_city, rating_range, review_range):
    min_rating, max_rating = rating_range
    min_reviews, max_reviews = review_range
    
    # Filter data based on city and filters
    filtered_df = df[(df['city'] == selected_city) & 
                     (df['rating'] >= min_rating) & (df['rating'] <= max_rating) &
                     (df['number_of_reviews'] >= min_reviews) & (df['number_of_reviews'] <= max_reviews)]
    
    # Return options for the restaurant dropdown
    return [{'label': name, 'value': name} for name in filtered_df['rest_name']]

# Callback to update the restaurant details and generate a summary of comments
@app.callback(
    Output('graphs-container', 'children'),
    Input('restaurant-dropdown', 'value'),
    Input('city-dropdown', 'value')
)
def update_restaurant_details(selected_restaurant, selected_city):
    if not selected_restaurant:
        return []  # No display if no restaurant is selected
    
    # Filter data to get the specific restaurant's details
    restaurant_data = df[(df['city'] == selected_city) & (df['rest_name'] == selected_restaurant)].iloc[0]
    
    # Extract specific fields
    image_url = restaurant_data['image_url']
    restaurant_url = restaurant_data['url']  # Assuming 'url' is the column name for restaurant link
    about_rest = restaurant_data['about_rest']
    ambience = restaurant_data['ambience']
    food = restaurant_data['food']
    service = restaurant_data['service']
    value = restaurant_data['value']
    comments = restaurant_data['comments'] if pd.notna(restaurant_data['comments']) else "No comments available"

    # Generate summary of comments using OpenAI
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": "You are a helpful assistant. Summarize the following restaurant reviews."
                },
                {
                    "role": "user",
                    "content": comments
                }
            ],
            model="gpt-3.5-turbo",
        )
        summary = chat_completion.choices[0].message.content
    except Exception as e:
        summary = f"An error occurred while summarizing comments: {str(e)}"

    # Display the restaurant's image as clickable link, about section, and ratings, along with the summary
    return [
        html.A(
            html.Img(src=image_url, style={'width': '500px', 'height': 'auto', 'object-fit': 'cover'}), 
            href=restaurant_url, target="_blank"
        ),
        html.H3("About the Restaurant"),
        html.P(about_rest),
        html.H3("Ratings"),
        html.P(f"Ambience: {ambience}/5"),
        html.P(f"Food: {food}/5"),
        html.P(f"Service: {service}/5"),
        html.P(f"Value: {value}/5"),
        html.H3("Summary of Comments"),
        html.P(summary)
    ]

if __name__ == '__main__':
    app.run_server(debug=True, port=8055)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8055/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 114, in update_restaurant_details(
#     selected_restaurant='Mrs. Fish',
#     selected_city='Chicago'
# )
#     111     return []  # No display if no restaurant is selected
#     113 # Filter data to get the specific restaurant's details
# --> 114 restaurant_data = df[(df['city'] == selected_city) & (df['rest_name'] == selected_restaurant)].iloc[0]
#         selected_restaurant = 'Mrs. Fish'
#         df =                                                    url  \
# 0    https://www.opentable.com/r/blue-fire-restaura...
# 1    https://www.opentable.com/turquoise?corrid=bb5...
# 2    https://www.opentable.com/r/cira-chicago?corri...
# 3    https://www.opentable.com/r/elia-chicago?corri...
# 4    https://www.opentable.com/r/blanco-cocina-and-...
# ..                                                 ...
# 261  https://www.opentable.com/r/texas-de-brazil-ca...
# 262  https://www.opentable.com/r/bjs-restaurant-and...
# 263  https://www.opentable.com/brigantine-escondido...
# 264  https://www.opentable.com/r/the-compass-carlsb...
# 265  https://www.opentable.com/r/heritage-barbecue-...
#
#                                    rest_name  number_of_reviews  rating  \
# 0                       Blue Fire Restaurant                 22     4.0
# 1                                  Turquoise               1203     4.7
# 2                                       Cira               1738     4.6
# 3                                       Elia                179     4.2
# 4        Blanco Cocina + Cantina - Oak Brook               1240     4.3
# ..                                       ...                ...     ...
# 261               Texas de Brazil - Carlsbad               1571     4.3
# 262  BJ's Restaurant & Brewhouse - Escondido                173     4.1
# 263                     Brigantine Escondido               1629     4.5
# 264                              The Compass                  5     4.0
# 265              Heritage Barbecue Oceanside                  4     4.4
#
#                  food_type         coupon  food  service  ambience  value  \
# 0    Contemporary European  $30 and under   4.4      4.3       4.1    4.0
# 1            Mediterranean  $30 and under   4.7      4.6       4.6    4.5
# 2            Mediterranean  $30 and under   4.5      4.5       4.6    4.3
# 3            Mediterranean  $30 and under   4.0      4.2       4.4    4.0
# 4                  Mexican  $30 and under   4.3      4.2       4.3    4.0
# ..                     ...            ...   ...      ...       ...    ...
# 261             Steakhouse   $50 and over   4.3      4.3       4.2    4.0
# 262               American  $30 and under   4.3      4.2       4.2    4.3
# 263                Seafood  $30 and under   4.5      4.7       4.4    4.2
# 264               American  $30 and under   4.1      4.0       3.9    3.7
# 265               Barbecue  $30 and under   4.2      4.8       4.4    4.2
#
#                                             about_rest  \
# 0    Blue Fire is located in Elmwood Park, Illinois...
# 1    Turquoise Restaurant was established in 2002 i...
# 2    Cira is a modern, Mediterranean restaurant, se...
# 3    Elia features Mediterranean inspired cuisine, ...
# 4    Blanco is more than your typical Mexican resta...
# ..                                                 ...
# 261  Texas de Brazil, is a Brazilian steakhouse, or...
# 262  Time counts at BJ's Restaurant & Brewhouse. Si...
# 263  A San Diego tradition since 1969, the Briganti...
# 264  Compass is a delicious eatery tucked away in t...
# 265  Experience the essence of Craft Barbecue inspi...
#
#                                               comments  \
# 0    Read more Hi guys. Everything was good. Just t...
# 1    Read more Turquoise has been reliably very goo...
# 2    Read more We loved the cozy booths and the DJ ...
# 3    Read more Amazing and delicious Turkish food. ...
# 4    Read more You must remember to request chip & ...
# ..                                                 ...
# 261  One of the best churrascaria experiences we've...
# 262  Read more We were seated immediately having a ...
# 263  Read more Marie was amazing as our server.  Ev...
# 264  Good food, good service.\nHhhhhhhhhhhhhhhhhhhh...
# 265  Read more I've been to the San Juan Capistrano...
#
#                                              image_url       city City
# 0    https://resizer.otstatic.com/v2/photos/xlarge/...    Chicago  NaN
# 1    https://resizer.otstatic.com/v2/photos/xlarge/...    Chicago  NaN
# 2    https://resizer.otstatic.com/v2/photos/xlarge/...    Chicago  NaN
# 3    https://resizer.otstatic.com/v2/photos/xlarge/...    Chicago  NaN
# 4    https://resizer.otstatic.com/v2/photos/xlarge/...    Chicago  NaN
# ..                                                 ...        ...  ...
# 261  https://resizer.otstatic.com/v2/photos/xlarge/...  San Diego  NaN
# 262  https://resizer.otstatic.com/v2/photos/xlarge/...  San Diego  NaN
# 263  https://resizer.otstatic.com/v2/photos/xlarge/...  San Diego  NaN
# 264  https://resizer.otstatic.com/v2/photos/xlarge/...  San Diego  NaN
# 265  https://resizer.otstatic.com/v2/photos/xlarge/...  San Diego  NaN
#
# [1800 rows x 15 columns]
#         selected_city = 'Chicago'
#     116 # Extract specific fields
#     117 image_url = restaurant_data['image_url']
#
# File ~/Desktop/Project_7/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(
#     self=<pandas.core.indexing._iLocIndexer object>,
#     key=0
# )
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#         axis = 0
#         maybe_callable = 0
#         self = <pandas.core.indexing._iLocIndexer object at 0x1145cad50>
#
# File ~/Desktop/Project_7/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(
#     self=<pandas.core.indexing._iLocIndexer object>,
#     key=0,
#     axis=0
# )
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#         key = 0
#         axis = 0
#         self = <pandas.core.indexing._iLocIndexer object at 0x1145cad50>
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/Desktop/Project_7/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(
#     self=<pandas.core.indexing._iLocIndexer object>,
#     key=0,
#     axis=0
# )
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
